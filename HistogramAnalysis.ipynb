# %%
from google.colab import drive
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/My Drive/pcdpunya/kucing.jpg'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
i = cv2.imread(path)
i = cv2.cvtColor(i, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(i)
plt.axis('off')
plt.show()

# %%
gs = cv2.cvtColor(i, cv2.COLOR_RGB2GRAY)
plt.imshow(gs, cmap='gray')
plt.axis('off')
plt.show()

# %%
_, bn = cv2.threshold(gs, 127, 255, cv2.THRESH_BINARY)
plt.imshow(bn, cmap='gray')
plt.axis('off')
plt.show()

# %%
r = cv2.calcHist([i], [0], None, [256], [0, 256])
g = cv2.calcHist([i], [1], None, [256], [0, 256])
b = cv2.calcHist([i], [2], None, [256], [0, 256])

plt.plot(r, color='red')
plt.plot(g, color='green')
plt.plot(b, color='blue')
plt.xlim([0, 256])
plt.title('Histogram RGB')
# Out:
# Text(0.5, 1.0, 'Histogram RGB')

# %%
plt.hist(gs.ravel(), 256, [0, 256], color='gray')
plt.title('Histogram Grayscale')
# Out:
# /tmp/ipython-input-1753309280.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gs.ravel(), 256, [0, 256], color='gray')
# Text(0.5, 1.0, 'Histogram Grayscale')

# %%
plt.hist(bn_01.ravel(), bins=[-0.5, 0.5, 1.5], color='black', rwidth=0.8)
plt.xticks([0, 1])
plt.title('Histogram Biner')
plt.show()

# %%
red = i[:, :, 0]
green = i[:, :, 1]
blue = i[:, :, 2]

merah = np.zeros_like(i)
hijau = np.zeros_like(i)
biru = np.zeros_like(i)

merah[:, :, 0] = red
hijau[:, :, 1] = green
biru[:, :, 2] = blue

# %%
plt.imshow(merah)
plt.title('Kanal Merah')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1076.5), np.float64(-0.5))

# %%
plt.hist(red.ravel(), 256, [0, 256], color='red')
plt.title('Histogram Kanal Merah')
# Out:
# /tmp/ipython-input-934648804.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(red.ravel(), 256, [0, 256], color='red')
# Text(0.5, 1.0, 'Histogram Kanal Merah')

# %%
plt.imshow(hijau)
plt.title('Kanal Hijau')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1076.5), np.float64(-0.5))

# %%
plt.hist(green.ravel(), 256, [0, 256], color='green')
plt.title('Histogram Kanal Hijau')
# Out:
# /tmp/ipython-input-3144174974.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(green.ravel(), 256, [0, 256], color='green')
# Text(0.5, 1.0, 'Histogram Kanal Hijau')

# %%
plt.imshow(biru)
plt.title('Kanal Biru')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(735.5), np.float64(1076.5), np.float64(-0.5))

# %%
plt.hist(blue.ravel(), 256, [0, 256], color='blue')
plt.title('Histogram Kanal Biru')
# Out:
# /tmp/ipython-input-1836191163.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(blue.ravel(), 256, [0, 256], color='blue')
# Text(0.5, 1.0, 'Histogram Kanal Biru')
